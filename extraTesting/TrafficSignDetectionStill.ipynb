# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage import feature

# %% [markdown]
# # RED COLOUR DETECTION

# %%
frame = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\Screenshot (11).png')

frame1 = np.copy(frame)

# frame = cv2.imread(r'C:\Users\Ankur Jain\Pictures\Screenshots\1.png')
# frame = cv2.resize(frame,(700,500))

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

lower1 = np.array([0,120,70], np.uint8)
upper1 = np.array([10, 255, 255], np.uint8)
mask1 = cv2.inRange(hsv, lower1, upper1)

lower2 = np.array([170,120,70], np.uint8)
upper2 = np.array([180, 255, 255], np.uint8)
mask2 = cv2.inRange(hsv, lower2, upper2)

mask = mask1+mask2
kernel = np.ones((3,3),np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

res = cv2.bitwise_and(frame, frame, mask = mask)

contours, hierachy = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    approx = cv2.approxPolyDP(cnt, 0.01*cv2.arcLength(cnt, True), True)
    x = approx.ravel()[0]
    y = approx.ravel()[1]
#     print(area, len(approx))
#     cv2.drawContours(frame, [approx], 0, (0, 0, 0), 3)
    if area>500:
        sides = len(approx)
        if ((sides > 10 and sides < 20) or sides==5 or sides==8 or sides==3):
            cv2.drawContours(frame1, [approx], -1, (0, 255, 0), 3)
            print(len(approx))

cv2.imshow("Frame",frame)
cv2.imshow("Frame1", frame1)
cv2.imshow("MASK",mask)
cv2.imshow("Res",res)

key = cv2.waitKey(0)
if (key==27):
    cv2.destroyAllWindows()
# Out:
# 8
# 11
# 12
# 11
# 11
# 19

# %%
import cv2
import numpy as np

# Load image 
image = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\images (1).jpg', 0) 

cv2.imshow("Frame", image)

# Set our filtering parameters 
# Initialize parameter settiing using cv2.SimpleBlobDetector 
params = cv2.SimpleBlobDetector_Params() 

# Set Area filtering parameters 
params.filterByArea = True
params.minArea = 100

# Set Circularity filtering parameters 
params.filterByCircularity = True
params.minCircularity = 0.9

# Set Convexity filtering parameters 
params.filterByConvexity = True
params.minConvexity = 0.2
	
# Set inertia filtering parameters 
params.filterByInertia = True
params.minInertiaRatio = 0.01

# Create a detector with the parameters 
detector = cv2.SimpleBlobDetector_create(params) 
	
# Detect blobs 
keypoints = detector.detect(image) 

# Draw blobs on our image as red circles 
blank = np.zeros((1, 1)) 
blobs = cv2.drawKeypoints(image, keypoints, blank, (0, 255, 0), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 

number_of_blobs = len(keypoints) 
text = "Number of Circular Blobs: " + str(len(keypoints)) 
cv2.putText(blobs, text, (20, 550), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 100, 255), 2) 

# Show blobs 
cv2.imshow("Filtering Circular Blobs Only", blobs) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %% [markdown]
# # EDGE DETECTION USING SOBEL AND LAPLACIAN METHOD

# %%
frame = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\images (12).jpg') 

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV) 

sobelx = cv2.Sobel(frame,cv2.CV_64F,1,0,ksize=5) 

sobely = cv2.Sobel(frame,cv2.CV_64F,0,1,ksize=5) 

laplacian = cv2.Laplacian(frame,cv2.CV_64F) 

cv2.imshow('sobelx',sobelx) 
cv2.imshow('sobely',sobely) 
cv2.imshow('laplacian',laplacian) 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %% [markdown]
# # CIRCLE DETECTION

# %%
img = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\images (12).jpg', cv2.IMREAD_COLOR) 

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

gray_blurred = cv2.blur(gray, (3, 3)) 

cv2.imshow("one",gray)
cv2.imshow("two",gray_blurred)

detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, 20, param1 = 50, param2 = 30, minRadius = 1, maxRadius = 40) 

if detected_circles is not None: 

    detected_circles = np.uint16(np.around(detected_circles)) 

    for pt in detected_circles[0, :]: 
        a, b, r = pt[0], pt[1], pt[2] 

    cv2.circle(img, (a, b), r, (0, 255, 0), 2) 

    cv2.circle(img, (a, b), 1, (0, 0, 255), 3) 
    cv2.imshow("Detected Circle", img) 
    cv2.waitKey(0) 
    cv2.destroyAllWindows()

# %% [markdown]
# # CANNY EDGE DETECTION

# %%
import cv2 
import numpy as np 

#image = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\images (12).jpg') 
image1 = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\images (12).jpg') 
image = np.copy(image1)

#gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 

def empty(x):
    pass

gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
gray1 = cv2.bilateralFilter(gray1,9,75,75)

cv2.namedWindow("Parameter")
cv2.createTrackbar("Threshold1","Parameter",150,255,empty)
cv2.createTrackbar("Threshold2","Parameter",255,255,empty)


while(True):
    
    threshold1 = cv2.getTrackbarPos("Threshold1", "Parameter")
    threshold2 = cv2.getTrackbarPos("Threshold2", "Parameter")

#     edged1 = cv2.Canny(gray1, 30, 200)
    edged1 = cv2.Canny(gray1, 150, 200)
#     edged1 = cv2.Canny(gray1, threshold1, threshold2) 

    #contours, hierarchy = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
    contours1, hierarchy1 = cv2.findContours(edged1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 

    #cv2.imshow('Canny Edges After Contouring', edged) 
    cv2.imshow('Canny1 Edges After Contouring', edged1) 

    #print("Number of Contours found = " + str(len(contours)))
    print("Number of Contours found = " + str(len(contours1)))

    #cv2.drawContours(image, contours, -1, (0, 255, 0), 3)
    cv2.drawContours(image1, contours1, -1, (0, 255, 0), 3)

    cv2.imshow('Cnts', image) 
    cv2.imshow('Cnts1', image1) 
    if (cv2.waitKey(0)):
        break
    
cv2.destroyAllWindows()
# Out:
# Number of Contours found = 70

# %% [markdown]
# # CIRCLE DETECION USING HOUGH TRANSFORMATION

# %%
import cv2
import numpy as np

# img = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\images (12).jpg',0)
# img = cv2.medianBlur(img,5)
# cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
image2 = np.copy(image)
circles = cv2.HoughCircles(edged1,cv2.HOUGH_GRADIENT,1,20,
                            param1=50,param2=30,minRadius=40,maxRadius=100)
try:
    circles = np.uint16(np.around(circles))
    for i in circles[0,:]:
        cv2.circle(image2,(i[0],i[1]),i[2],(0,255,0),2)
#         cv2.circle(image2,(i[0],i[1]),2,(0,0,255),3)

#     res = cv2.bitwise_and(edged1, image, mask = cv2.THRESH_BINARY)
    cv2.imshow("image", image)
    cv2.imshow("Canny", edged1)
#     cv2.imshow("Result",res)
    cv2.imshow('detected circles',image2)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
except():
    cv2.destroyAllWindows()

# %%
import numpy as np
import cv2


img = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\download (7).jpg', cv2.IMREAD_COLOR)
# img = cv2.resize(img,(700,500))
# Convert to gray-scale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Blur the image to reduce noise
# img_blur = cv2.Blur(gray, 5)

img_blur = cv2.bilateralFilter(gray,9,15,15)

# img = np.copy(frame)
# img = cv2.resize(img,(700,500))

cv2.imshow("gray",gray)
cv2.imshow("blur", img_blur)

# img_blur = np.copy(mask)
# Apply hough transform on the image


# circles = cv2.HoughCircles(img_blur, cv2.HOUGH_GRADIENT, 80, img.shape[0]/64, param1=200, param2=100, minRadius=10, maxRadius=90)
circles = cv2.HoughCircles(img_blur,  cv2.HOUGH_GRADIENT, 10, 60, param1 = 50, param2 = 60, minRadius = 1, maxRadius = 40) 

# Draw detected circles
if circles is not None:
    circles = np.uint16(np.around(circles))
    for i in circles[0, :]:
        # Draw outer circle
        cv2.circle(img, (i[0], i[1]), i[2], (0, 255, 0), 2)
        # Draw inner circle
        cv2.circle(img, (i[0], i[1]), 2, (0, 0, 255), 3)
cv2.imshow("Image",img)
# cv2.imshow("mask", mask)
    
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # RED and BLUE Detection

# %%
frame = cv2.imread(r'C:\Users\Ankur Jain\Desktop\signs\images (11).jpg')

frame1 = np.copy(frame)

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

lower1 = np.array([0,120,70], np.uint8)
upper1 = np.array([10, 255, 255], np.uint8)
mask1 = cv2.inRange(hsv, lower1, upper1)

lower2 = np.array([170,120,70], np.uint8)
upper2 = np.array([180, 255, 255], np.uint8)
mask2 = cv2.inRange(hsv, lower2, upper2)

lower3 = np.array([94,127,20], np.uint8)
upper3 = np.array([126,255,200], np.uint8)
mask3 = cv2.inRange(hsv, lower3, upper3)


im_prep_red = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
# im_prep_red = cv2.resize(im_gray_red, (64, 64))
fd_red, h_red = feature.hog(im_prep_red, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(4, 4),
                                        transform_sqrt=False, block_norm="L1", visualise=True)

mask = mask1+mask2 #+mask3
kernel = np.ones((3,3),np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

res = cv2.bitwise_and(frame, frame, mask = mask)

# contours, hierachy = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# for cnt in contours:
#     area = cv2.contourArea(cnt)
#     approx = cv2.approxPolyDP(cnt, 0.01*cv2.arcLength(cnt, True), True)
#     x = approx.ravel()[0]
#     y = approx.ravel()[1]
# #     print(area, len(approx))
# #     cv2.drawContours(frame, [approx], 0, (0, 0, 0), 3)
#     if area>500:
#         sides = len(approx)
#         if ((sides > 10 and sides < 20) or sides==5 or sides==8 or sides==3):
#             cv2.drawContours(frame1, [approx], -1, (0, 255, 0), 3)
#             print(len(approx))

cv2.imshow("Frame",frame)
cv2.imshow("Frame1", hsv)
cv2.imshow("MASK",mask)
cv2.imshow("Res",res)
# cv2.imshow("Res1",fd_red)
cv2.imshow("Res2",h_red)

key = cv2.waitKey(0)
if (key==27):
    cv2.destroyAllWindows()
